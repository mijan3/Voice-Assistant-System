# %%
GEMINI_API_KEY="AIzaSyB8K1eWqC0KKIVMeXLdc0eGof-S5qXKUIY"

# %%
print("GEMINI_API_KEY set successfully.")
# Out:
# GEMINI_API_KEY set successfully.

# %%
import google.generativeai as genai
genai.configure(api_key=GEMINI_API_KEY)

model=genai.GenerativeModel("gemini-2.5-flash")

# %%
user_input = "Explain the theory of relativity in simple terms."
prompt =f"Answar the following question in short: Question {user_input}"
response=model.generate_content(prompt)
print(response.text)
# Out:
# It states that space and time are not absolute but are relative to an observer's motion, especially considering the constant speed of light. This means time can pass differently and distances can change depending on your speed. It also explains that mass and energy are interchangeable (E=mc²) and that gravity is the curvature of space-time caused by massive objects.
